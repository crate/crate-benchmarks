# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from crate.client import connect
conn = connect('localhost:4200')
cursor = conn.cursor()
cursor.execute('select runtime_stats from benchmarks order by ended desc limit 1')
last_result = cursor.fetchone()[0]
values = last_result['samples']
plt.hist(values)
# Out:
# <img src="data:image/png;base64,...">
# (array([ 481.,    6.,    7.,    1.,    4.,    0.,    0.,    0.,    0.,    1.]),
#  array([  1. ,   2.7,   4.4,   6.1,   7.8,   9.5,  11.2,  12.9,  14.6,
#          16.3,  18. ]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(values)
# Out:
# <img src="data:image/png;base64,...">
